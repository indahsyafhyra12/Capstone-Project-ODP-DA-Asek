# %% [markdown]
# ## Resources
#
# ### Capstone Project — Screening Credit Agentic AI
#
# Capstone project ODP Data Analyst Batch 367 (BNI) — Tim **eLo**.
#
# Author: **Muhammad Nevin** dan **Indah Syafhyra Nurjanah**
#
# Sistem *agentic AI* untuk membantu proses screening pengajuan kredit retail/UMKM, menggabungkan model machine learning (skor kelayakan 5C) dengan beberapa agent khusus yang masing-masing memeriksa satu aspek pengajuan (identitas, riwayat kredit, keuangan, cashflow, agunan, daftar hitam nasional, risiko) lalu merangkumnya jadi satu laporan keputusan.
#
# ### Latar Belakang
#
# Analis kredit di bank harus mengecek banyak sumber data berbeda untuk satu pengajuan — data kependudukan (Dukcapil), riwayat kredit (SLIK OJK), daftar hitam nasional (DHN), legalitas agunan (ATR/BPN), laporan keuangan, dan mutasi rekening — lalu menilainya berdasarkan prinsip 5C (*Character, Capacity, Capital, Collateral, Condition*). Proyek ini mencoba mengotomatisasi sebagian proses tersebut: model ML memberi skor awal kelayakan, sementara agent-agent AI memeriksa tiap aspek 5C secara terpisah dan menyusun narasi/laporan yang bisa jadi bahan pertimbangan analis manusia.

# %%
import tensorflow as tf

if tf.test.is_gpu_available():
    print("GPU is available and being used!")
    print("GPU device name:", tf.test.gpu_device_name())
else:
    print("GPU is not available or not being used. Running on CPU.")
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_2868/3375387878.py:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU is not available or not being used. Running on CPU.

# %%
import os

# Clone the repository
# !git clone https://github.com/indahsyafhyra12/Capstone-Project-ODP-DA-Asek.git

# Verify the repository has been cloned by listing its contents
repo_name = 'Capstone-Project-ODP-DA-Asek'
if os.path.exists(repo_name):
    print(f"Repository '{repo_name}' cloned successfully.")
    print(f"Contents of '{repo_name}':")
    # !ls -F {repo_name}
else:
    print(f"Failed to clone repository '{repo_name}'.")
# Out:
# Cloning into 'Capstone-Project-ODP-DA-Asek'...
# remote: Enumerating objects: 590, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 590 (delta 64), reused 74 (delta 33), pack-reused 475 (from 1)
# Receiving objects: 100% (590/590), 53.90 MiB | 30.29 MiB/s, done.
# Resolving deltas: 100% (209/209), done.
# Repository 'Capstone-Project-ODP-DA-Asek' cloned successfully.
# Contents of 'Capstone-Project-ODP-DA-Asek':
# app_premium.py	       models/	   README.md		       src/
# app.py		       notebooks/  requirements-notebooks.txt  tests/
# data/		       pages/	   requirements.txt	       utils/
# data_dictionary_v2.md  pages_v2/   Resources_Pendukung/

# %%
# !ls
# Out:
# Capstone-Project-ODP-DA-Asek  sample_data

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸
# added 22 packages in 3s
# ⠸
# ⠸3 packages are looking for funding
# ⠸  run `npm fund` for details
# ⠸

# %%
import os

# Change to the repository directory
repo_path = 'Capstone-Project-ODP-DA-Asek'
if os.path.exists(repo_path) and os.path.isdir(repo_path):
    os.chdir(repo_path)
    print(f"Changed directory to: {os.getcwd()}")

    # !pwd

    # Install dependencies from requirements.txt
    # !pip install -r requirements.txt

    # Run the Streamlit app
    # !streamlit run app_premium.py &>/content/logs.txt &
else:
    print(f"Error: Repository directory '{repo_path}' not found.")

import time
time.sleep(5)  # kasih waktu Streamlit start dulu

# --- ganti bagian ini ---
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
# !./cloudflared-linux-amd64 tunnel --url http://localhost:8501
# Out:
# Changed directory to: /content/Capstone-Project-ODP-DA-Asek
# /content/Capstone-Project-ODP-DA-Asek
# Collecting plotly==6.9.0 (from -r requirements.txt (line 3))
#   Downloading plotly-6.9.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting streamlit==1.51.0 (from -r requirements.txt (line 4))
#   Downloading streamlit-1.51.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting bitsandbytes>=0.46.1 (from -r requirements.txt (line 8))
#   Downloading bitsandbytes-0.50.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.13/dist-packages (from plotly==6.9.0->-r requirements.txt (line 3)) (2.25.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from plotly==6.9.0->-r requirements.txt (line 3)) (26.3)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (8.4.2)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (2.1.3)
# Collecting packaging (from plotly==6.9.0->-r requirements.txt (line 3))
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (5.29.6)
# Requirement already satisfied: pyarrow<22,>=7.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (4.16.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (6.0.0)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit==1.51.0->-r requirements.txt (line 4))
#   Downloading gitpython-3.1.60-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit==1.51.0->-r requirements.txt (line 4))
#   Downloading pydeck-0.9.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.13/dist-packages (from streamlit==1.51.0->-r requirements.txt (line 4)) (6.5.7)
# Requirement already satisfied: torch<3,>=2.4 in /usr/local/lib/python3.13/dist-packages (from bitsandbytes>=0.46.1->-r requirements.txt (line 8)) (2.11.0+cpu)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.13/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (4.26.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.51.0->-r requirements.txt (line 4))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=1.4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=1.4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<3,>=1.4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.27->streamlit==1.51.0->-r requirements.txt (line 4)) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.27->streamlit==1.51.0->-r requirements.txt (line 4)) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.27->streamlit==1.51.0->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<3,>=2.27->streamlit==1.51.0->-r requirements.txt (line 4)) (2026.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes>=0.46.1->-r requirements.txt (line 8)) (3.32.4)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes>=0.46.1->-r requirements.txt (line 8)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes>=0.46.1->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes>=0.46.1->-r requirements.txt (line 8)) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch<3,>=2.4->bitsandbytes>=0.46.1->-r requirements.txt (line 8)) (2025.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.51.0->-r requirements.txt (line 4))
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (2026.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit==1.51.0->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch<3,>=2.4->bitsandbytes>=0.46.1->-r requirements.txt (line 8)) (1.3.0)
# Downloading plotly-6.9.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 79.9 MB/s eta 0:00:00
# Downloading streamlit-1.51.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 91.9 MB/s eta 0:00:00
# Downloading bitsandbytes-0.50.2-py3-none-manylinux_2_24_x86_64.whl (43.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 MB 13.6 MB/s eta 0:00:00
# Downloading gitpython-3.1.60-py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.9/221.9 kB 14.6 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.5 MB/s eta 0:00:00
# Downloading pydeck-0.9.3-py2.py3-none-any.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 67.9 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.6 MB/s eta 0:00:00
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, packaging, pydeck, plotly, gitdb, gitpython, bitsandbytes, streamlit
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.3
#     Uninstalling packaging-26.3:
#       Successfully uninstalled packaging-26.3
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
# Successfully installed bitsandbytes-0.50.2 gitdb-4.0.12 gitpython-3.1.60 packaging-25.0 plotly-6.9.0 pydeck-0.9.3 smmap-5.0.3 streamlit-1.51.0
# 2026-08-28T01:05:33Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-08-28T01:05:33Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-08-28T01:05:37Z INF +--------------------------------------------------------------------------------------------+
# 2026-08-28T01:05:37Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-08-28T01:05:37Z INF |  https://cheaper-sensitivity-toolbar-organizer.trycloudflare.com                           |
# 2026-08-28T01:05:37Z INF +--------------------------------------------------------------------------------------------+
# 2026-08-28T01:05:37Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-08-28T01:05:37Z INF Version 2026.8.2 (Checksum fcfb02b575a52ca1af2e3267af4e1517bcdeb30ac48c834c69abaed3c0576ad2)
# 2026-08-28T01:05:37Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-08-28T01:05:37Z INF Settings: map[ha-connections:1 protocol:quic url:http://localhost:8501]
# 2026-08-28T01:05:37Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-08-28T01:05:37Z INF Generated Connector ID: 3685f77b-d3e2-4b6d-990b-da5721c13c16
# 2026-08-28T01:05:37Z INF Initial protocol quic
# 2026-08-28T01:05:37Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-08-28T01:05:37Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026/08/28 01:05:37 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-08-28T01:05:37Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-08-28T01:05:37Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-08-28T01:05:37Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026-08-28T01:05:37Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.192.227
# 2026-08-28T01:05:38Z INF Registered tunnel connection connIndex=0 connection=ef38cc9d-7a84-4359-9a43-45a63c46c6d3 event=0 ip=198.41.192.227 location=ams13 protocol=quic
# 2026-08-28T01:05:43Z INF +-------------------------------------------------------------------------------------+
# 2026-08-28T01:05:43Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-08-28T01:05:43Z INF +-------------------------------------------------------------------------------------+
# 2026-08-28T01:05:43Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-08-28T01:05:43Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-08-28T01:05:43Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-08-28T01:05:43Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-08-28T01:05:43Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-08-28T01:05:43Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-08-28T01:05:43Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-08-28T01:05:43Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-08-28T01:05:43Z INF |                                                                                     |
# 2026-08-28T01:05:43Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-08-28T01:05:43Z INF +-------------------------------------------------------------------------------------+
# 2026-08-28T01:05:43Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=27334769-f507-411e-9324-5b7a05743bd2 status=pass target=region1.v2.argotunnel.com
# 2026-08-28T01:05:43Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=27334769-f507-411e-9324-5b7a05743bd2 status=pass target=region2.v2.argotunnel.com
# 2026-08-28T01:05:43Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=27334769-f507-411e-9324-5b7a05743bd2 status=pass target=region1.v2.argotunnel.com
# 2026-08-28T01:05:43Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=27334769-f507-411e-9324-5b7a05743bd2 status=pass target=region2.v2.argotunnel.com
# 2026-08-28T01:05:43Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=27334769-f507-411e-9324-5b7a05743bd2 status=pass target=region1.v2.argotunnel.com
# 2026-08-28T01:05:43Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=27334769-f507-411e-9324-5b7a05743bd2 status=pass target=region2.v2.argotunnel.com
# 2026-08-28T01:05:43Z INF precheck component="Cloudflare API" details="API is reachable" run_id=27334769-f507-411e-9324-5b7a05743bd2 status=pass target=api.cloudflare.com:443
# 2026-08-28T01:05:43Z INF precheck complete hard_fail=false run_id=27334769-f507-411e-9324-5b7a05743bd2 suggested_protocol=quic
# 2026-08-28T01:05:52Z INF Initiating graceful shutdown due to signal interrupt ...
# ^C

# %% [markdown]
# Aplikasi Streamlit telah berjalan. Silakan klik tautan yang muncul di output sel di atas (`https://<nama-anda>.trycloudflare.com`) untuk mengakses aplikasi.
